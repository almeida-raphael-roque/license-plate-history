# %%
import awswrangler as awr
import pandas as pd

# %% [markdown]
# df

# %%
file_path = r"C:\Users\raphael.almeida\Documents\Processos\historico_placas\sql\all_boards.sql"
with open (file_path, 'r') as r:
    query = r.read()

df = awr.athena.read_sql_query(query, database='silver')
# Out:
#         coverage                          beneficio    placa  \
# 0          19802                             VIDROS  NDA1E06
# 1          19800               ASSISTÊNCIA 24 HORAS  NDA1E06
# 2          19796  REPARAÇÃO OU REPOSIÇÃO DO VEÍCULO  NDA1E06
# 3          19795              REPARAÇÃO A TERCEIROS  NCV0423
# 4          19794               ASSISTÊNCIA 24 HORAS  NCV0423
# ...          ...                                ...      ...
# 685137    659759                         RASTREADOR  IVQ9J57
# 685138    497652                         RASTREADOR  AXF3B90
# 685139    497649               ASSISTÊNCIA 24 HORAS  AXF3B90
# 685140    496155              REPARAÇÃO A TERCEIROS  IVQ9969
# 685141    496153  REPARAÇÃO OU REPOSIÇÃO DO VEÍCULO  IVQ9969
#
#                    chassi  id_placa  matricula  conjunto data_registro  \
# 0       9534N8249BR162477      9972      20814      3225    2023-11-27
# 1       9534N8249BR162477      9972      20814      3225    2023-11-27
# 2       9534N8249BR162477      9972      20814      3225    2023-11-27
# 3       9534N8248BR143466      9970      20814      3225    2023-11-27
# 4       9534N8248BR143466      9970      20814      3225    2023-11-27
# ...                   ...       ...        ...       ...           ...
# 685137  9BVAG20C8EE818058    155768      45441    137663    2024-03-21
# 685138  93ZE2HMH0D8922179    133842      45441    111740    2022-07-29
# 685139  93ZE2HMH0D8922179    133842      45441    111740    2022-07-29
# 685140  9BVAG20C7EE816102    132701      45441    111475    2022-07-27
# 685141  9BVAG20C7EE816102    132701      45441    111475    2022-07-27
#
#        data_cancelamento_conjunto data_ativacao_conjunto status_conjunto  \
# 0                      2024-01-25             2023-11-27       CANCELADO
# 1                      2024-01-25             2023-11-27       CANCELADO
# 2                      2024-01-25             2023-11-27       CANCELADO
# 3                      2024-01-25             2023-11-27       CANCELADO
# 4                      2024-01-25             2023-11-27       CANCELADO
# ...                           ...                    ...             ...
# 685137                 2025-04-14             2024-03-29      FINALIZADO
# 685138                 2023-08-14             2022-07-29      FINALIZADO
# 685139                 2023-08-14             2022-07-29      FINALIZADO
# 685140                 2023-08-13             2022-07-28      FINALIZADO
# 685141                 2023-08-13             2022-07-28      FINALIZADO
#
#        data_ativacao_beneficio status_beneficio   empresa data_atualizacao
# 0                   2023-11-27        CANCELADO    Stcoop       2024-01-25
# 1                   2023-11-27        CANCELADO    Stcoop       2024-01-25
# 2                   2023-11-27        CANCELADO    Stcoop       2024-01-25
# 3                   2023-11-27        CANCELADO    Stcoop       2024-01-25
# 4                   2023-11-27        CANCELADO    Stcoop       2024-01-25
# ...                        ...              ...       ...              ...
# 685137              2024-03-29            ATIVO  Segtruck       2024-06-19
# 685138              2022-07-29        CANCELADO  Segtruck       2024-08-19
# 685139              2022-07-29        CANCELADO  Segtruck       2024-08-19
# 685140              2022-07-28        CANCELADO  Segtruck       2024-08-19
# 685141              2022-07-28        CANCELADO  Segtruck       2024-08-19
#
# [685142 rows x 15 columns]

# %%
# Identificar as placas que possuem pelo menos os status "CANCELADO" e "ATIVO"
placas_com_ambos_status = df.groupby('placa')['status_conjunto'] \
                            .apply(lambda x: {'CANCELADO', 'ATIVO'}.issubset(set(x))) \
                            .loc[lambda x: x].index

# Filtrar o DataFrame completo para manter apenas essas placas
df_filtrado = df[df['placa'].isin(placas_com_ambos_status)]

df_filtrado
# Out:
#         coverage              beneficio    placa             chassi  id_placa  \
# 11         76172                 VIDROS  RTC8G06  953998TH0NR202588      8363
# 12         76170  REPARAÇÃO A TERCEIROS  RTC8G06  953998TH0NR202588      8363
# 13         76123             RASTREADOR  RTX4I90  953998TH6NR203020     20563
# 14         76122                 VIDROS  RTX4I90  953998TH6NR203020     20563
# 15         76121  REPARAÇÃO A TERCEIROS  RTX4I90  953998TH6NR203020     20563
# ...          ...                    ...      ...                ...       ...
# 685118    622312                 VIDROS  HLL2342  93ZE2HJ00C8907088    128117
# 685119    495638                 VIDROS  RMU4G79  9BM934241FS034109    127995
# 685123    495621             RASTREADOR  HLL2347  93ZE2HJ00C8906968    131727
# 685124    495616             RASTREADOR  HLL2342  93ZE2HJ00C8907088    128117
# 685125    495614   ASSISTÊNCIA 24 HORAS  HLL2342  93ZE2HJ00C8907088    128117
#
#         matricula  conjunto data_registro data_cancelamento_conjunto  \
# 11          20399     12277    2024-11-08                 2025-01-30
# 12          20399     12277    2024-11-08                 2025-01-30
# 13          20399     12268    2024-11-08                 2024-11-26
# 14          20399     12268    2024-11-08                 2024-11-26
# 15          20399     12268    2024-11-08                 2024-11-26
# ...           ...       ...           ...                        ...
# 685118      45436    131671    2023-07-07                 2024-07-26
# 685119      45436    111381    2022-07-26                       None
# 685123      45436    111381    2022-07-26                       None
# 685124      45436    111381    2022-07-26                       None
# 685125      45436    111381    2022-07-26                       None
#
#        data_ativacao_conjunto status_conjunto data_ativacao_beneficio  \
# 11                 2024-11-09       CANCELADO              2024-11-09
# 12                 2024-11-09       CANCELADO              2024-11-09
# 13                 2024-11-08       CANCELADO              2024-11-08
# 14                 2024-11-08       CANCELADO              2024-11-08
# 15                 2024-11-08       CANCELADO              2024-11-08
# ...                       ...             ...                     ...
# 685118             2023-07-28       CANCELADO              2023-07-28
# 685119             2022-07-28       RENOVAÇÃO              2022-07-28
# 685123             2022-07-28       RENOVAÇÃO              2022-07-28
# 685124             2022-07-28       RENOVAÇÃO              2022-07-28
# 685125             2022-07-28       RENOVAÇÃO              2022-07-28
#
#        status_beneficio   empresa data_atualizacao
# 11            CANCELADO    Stcoop       2025-01-30
# 12            CANCELADO    Stcoop       2025-01-30
# 13            CANCELADO    Stcoop       2024-11-26
# 14            CANCELADO    Stcoop       2024-11-26
# 15            CANCELADO    Stcoop       2024-11-26
# ...                 ...       ...              ...
# 685118        CANCELADO  Segtruck       2024-07-26
# 685119        RENOVAÇÃO  Segtruck       2023-07-29
# 685123        RENOVAÇÃO  Segtruck       2023-07-29
# 685124        RENOVAÇÃO  Segtruck       2023-07-29
# 685125        RENOVAÇÃO  Segtruck       2023-07-29
#
# [95098 rows x 15 columns]

# %%
# Ordenar por placa e data_registro para garantir a ordem cronológica
df_sorted = df.sort_values(['placa', 'data_registro'])

# Função para verificar se "ATIVO" aparece antes de "CANCELADO"
def ativo_antes_cancelado(grupo):
    status = grupo['status_conjunto'].values
    return 'ATIVO' in status and 'CANCELADO' in status and list(status).index('ATIVO') < list(status).index('CANCELADO')

# Identificar placas que atendem à condição
placas_ativo_antes_cancelado = df_sorted.groupby('placa').filter(ativo_antes_cancelado)['placa'].unique()

print("Placas com status ATIVO antes de CANCELADO:")
print(placas_ativo_antes_cancelado)
# Out:
# Placas com status ATIVO antes de CANCELADO:
# <StringArray>
# ['ABI6E48', 'ABI6F58', 'ABJ2425', 'ABZ6B69', 'AFD7H68', 'AKO2D69', 'ATM8H72',
#  'AUA8I08', 'AUB7E37', 'AXT1B71', 'AYC6B19', 'AYZ5A44', 'BCN7J85', 'BCN7J87',
#  'BDP1G34', 'CSK3I11', 'FDC9I09', 'FTP3G46', 'FTX5B85', 'GDS2E05', 'GVE3F38',
#  'HLY4B80', 'ICV2143', 'IVY4D91', 'JZN3A67', 'JZP3A67', 'MGY2G95', 'MXE5D35',
#  'NKO1H24', 'NRM7970', 'NRM7971', 'ONO1D65', 'ONO1G55', 'ONO2H35', 'OOM5C63',
#  'OOM5C64', 'OOM5E81', 'OOM5E82', 'QAJ3D40', 'QAJ3E40', 'QAU2A09', 'QAU2A19',
#  'QCS6268', 'QHL3B99', 'QJZ7772', 'QTZ9F45', 'RDU7E35', 'RHK6H06', 'RRL1C06',
#  'RRU3F97', 'RRU3G87', 'RRU3I27', 'RXK7B77', 'RYJ2E31', 'SEG7H19', 'SFH2G93',
#  'SLI3J78', 'SLI4C28', 'SLI4D88', 'SXN6I39', 'TAM3E07']
# Length: 61, dtype: string

# %%
df1 = df[df['placa']=='SLI4D88']
df1.sort_values('data_registro', ascending=False)
# Out:
#         coverage                        beneficio    placa             chassi  \
# 164907     55618                     CASCO (R/SR)  SLI4D88  9A9SRCAB2R1DK4028
# 73405      33419                     CASCO (R/SR)  SLI4D88  9A9SRCAB2R1DK4028
# 79257      33420  RASTREADOR REBOQUE/SEMIRREBOQUE  SLI4D88  9A9SRCAB2R1DK4028
#
#         id_placa  matricula  conjunto data_registro  \
# 164907      4850       5069      7519    2024-12-26
# 73405       4850       3426      4728    2024-10-30
# 79257       4850       3426      4728    2024-10-30
#
#        data_cancelamento_conjunto data_ativacao_conjunto status_conjunto  \
# 164907                 2025-05-05             2024-12-30       CANCELADO
# 73405                        None             2024-10-29           ATIVO
# 79257                        None             2024-10-29           ATIVO
#
#        data_ativacao_beneficio status_beneficio   empresa data_atualizacao
# 164907              2024-12-30        CANCELADO  Viavante       2025-05-05
# 73405               2024-10-31        CANCELADO  Viavante       2025-05-06
# 79257               2024-10-31        CANCELADO  Viavante       2025-05-06

# %% [markdown]
# DF_SETS

# %% [markdown]
# df_set

# %%
file_path = r"C:\Users\raphael.almeida\Documents\Processos\historico_placas\sql\all_boards_sets.sql"
with open (file_path, 'r') as r:
    query = r.read()

df_sets = awr.athena.read_sql_query(query, database='silver')

# %%
df_sets.sort_values('placa')
# Out:
#              placa                chassi  id_placa  matricula  conjunto  \
# 221365     AAT8826                 67639     32750      46009    114637
# 215324     AAT8826                 67639     32750      36372     59977
# 122352     AAT8826                 67639     32750      36372     57777
# 196771     AKC1D93     9A90710202SAC6332     18187      12145     70799
# 128668     AKC1D93     9A90710202SAC6332     18187      12145     22584
# ...            ...                   ...       ...        ...       ...
# 24353      ZZZ9999      528LKACKDXPPD244    186298       2149      2833
# 90727   ¨@%NBY5133  %¨#%$#¨%$82G5C054546      8255       1798     22573
# 158884  ¨@%NBY5133  %¨#%$#¨%$82G5C054546      8255      41355    107366
# 70507   ¨@%NBY5133  %¨#%$#¨%$82G5C054546      8255       1798     12952
# 187997  ¨@%NBY5133  %¨#%$#¨%$82G5C054546      8255      41355     76806
#
#        data_registro data_cancelamento_conjunto data_ativacao_conjunto  \
# 221365    2022-09-09                       None                   None
# 215324    2020-07-22                 2021-05-20             2020-07-22
# 122352    2020-06-10                       None             2020-06-10
# 196771    2021-02-09                       None             2021-02-10
# 128668    2019-05-24                       None             2019-05-25
# ...              ...                        ...                    ...
# 24353     2024-09-03                       None             2024-09-03
# 90727     2019-05-23                       None             2019-05-25
# 158884    2022-05-26                       None             2022-05-28
# 70507     2018-05-28                       None             2018-05-29
# 187997    2021-05-25                 2022-06-12             2021-05-27
#
#        status_conjunto   empresa              data_atualizacao
# 221365            NOVO  Segtruck 1754-08-30 22:43:41.128654848
# 215324       CANCELADO  Segtruck 2021-05-20 00:00:00.000000000
# 122352     SUBSTITUÍDO  Segtruck 2020-08-26 00:00:00.000000000
# 196771       RENOVAÇÃO  Segtruck 2022-02-11 00:00:00.000000000
# 128668       RENOVAÇÃO  Segtruck 2020-05-24 00:00:00.000000000
# ...                ...       ...                           ...
# 24353      SUBSTITUÍDO  Viavante 2025-04-22 00:00:00.000000000
# 90727        RENOVAÇÃO  Segtruck 2020-05-24 00:00:00.000000000
# 158884       RENOVAÇÃO  Segtruck 2023-05-29 00:00:00.000000000
# 70507        RENOVAÇÃO  Segtruck 2019-05-23 00:00:00.000000000
# 187997      FINALIZADO  Segtruck 2023-05-23 00:00:00.000000000
#
# [241774 rows x 11 columns]

# %%
# Identificar as placas que possuem pelo menos os status "CANCELADO" e "ATIVO"
placas_com_ambos_status = df_sets.groupby('placa')['status_conjunto'] \
                            .apply(lambda x: {'CANCELADO', 'ATIVO'}.issubset(set(x))) \
                            .loc[lambda x: x].index

# Filtrar o DataFrame completo para manter apenas essas placas
df_sets_filtrado = df_sets[df_sets['placa'].isin(placas_com_ambos_status)]

# %%
df_sets_sorted = df_sets.sort_values(['placa', 'data_registro'])

# Função para verificar a sequência ATIVO → CANCELADO → ATIVO
def ativo_cancelado_ativo(grupo):
    status = grupo['status_conjunto'].dropna().astype(str).values
    status_str = ' '.join(status)
    return 'ATIVO CANCELADO ATIVO' in status_str

# Identificar placas que atendem à condição
placas_ativo_cancelado_ativo = df_sets_sorted.groupby('placa').filter(ativo_cancelado_ativo)['placa'].unique()

print("Placas com sequência ATIVO → CANCELADO → ATIVO:")
print(placas_ativo_cancelado_ativo)
# Out:
# Placas com sequência ATIVO → CANCELADO → ATIVO:
# <StringArray>
# [  'AUA8I08',   'AYC6B19',   'AYZ5A44',   'CSK3I11',   'EZU2H14',   'IVY4D91',
#    'NKO1H24',   'NRM7970',   'NRM7971',   'OOM5C63',   'OOM5C64',   'OOM5E81',
#    'OOM5E82',   'QAJ3D40',   'QAJ3E40',   'QAU2A09',   'QAU2A19',   'RYJ2E31',
#  'SEM-PLACA',   'SWF1H56']
# Length: 20, dtype: string

# %%
df_sets1 = df_sets[df_sets['placa']=='SWF1H56']
df_sets1.sort_values('data_registro', ascending=False)
# Out:
#          placa             chassi  id_placa  matricula  conjunto  \
# 57486  SWF1H56  9BVRT60D3RE602433    186738       4568      6576
# 45578  SWF1H56  9BVRT60D3RE602433    186738        853      4301
# 29203  SWF1H56  9BVRT60D3RE602433    186738        853      4204
# 55529  SWF1H56  9BVRT60D3RE602433    186738        853       988
#
#       data_registro data_cancelamento_conjunto data_ativacao_conjunto  \
# 57486    2024-12-05                       None             2024-12-05
# 45578    2024-10-18                 2024-12-05             2024-09-16
# 29203    2024-10-16                       None             2024-06-13
# 55529    2024-06-13                 2024-12-05             2024-06-13
#
#       status_conjunto   empresa data_atualizacao
# 57486           ATIVO  Viavante       2025-03-18
# 45578       CANCELADO  Viavante       2024-12-05
# 29203           ATIVO  Viavante       2025-01-17
# 55529       CANCELADO  Viavante       2024-12-05
